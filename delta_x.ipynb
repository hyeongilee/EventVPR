# %%
for i in range(35):
    tum_file = open("../dataset/KH/rain/raw_txt_10000ms/2020_07_30_17_51_53/"+str(i)+"_output/reconstruction/localization_frame_trajectory_i.txt")
    
    L = list()
    while True:
        line = tum_file.readline()
        if not line:
            break
        L.append(line.split())
    delta = [round(float(L[-1][1])-float(L[0][1]),4),round(float(L[-1][2])-float(L[0][2]),4),round(float(L[-1][3])-float(L[0][3]),4),round(float(L[-1][4])-float(L[0][4]),4),round(float(L[-1][5])-float(L[0][5]),4),round(float(L[-1][6])-float(L[0][6]),4)]
    print(delta)
    tum_file.close()
# Out:
# [-0.0028, 0.0556, 0.3642, -0.0626, 0.0112, 0.0177]
# [-0.1992, 0.0576, 0.2648, -0.1561, -0.5549, 0.2214]
# [-0.1186, -0.0059, 0.2841, -0.2447, -0.6248, -0.0515]
# [-0.2687, 0.2081, 0.8483, -0.0516, -0.2966, 0.1545]
# [0.0262, 0.134, 0.4248, 0.0045, -0.0163, 0.0057]
# [0.3123, 0.0601, 0.5618, -0.0304, -0.0643, 0.0326]
# [0.0564, 0.1403, 0.4901, -0.1495, -0.0724, 0.0855]
# [0.0117, -0.0164, 0.0858, -0.1619, 0.0736, -0.081]
# [-0.0005, 0.0003, 0.0012, 0.0018, -0.004, 0.0087]
# [-0.5856, 0.345, 0.3067, 0.1588, -0.5032, 0.1293]
# [-0.0078, 0.0286, 0.0806, 0.0094, -0.0321, 0.0072]
# [-0.0683, 0.0518, 0.2178, -0.0416, -0.0636, 0.044]
# [0.102, 0.0635, 0.3482, 0.0094, 0.2599, -0.1435]
# [0.0484, 0.0838, 0.3818, 0.0347, 0.0745, -0.0277]
# [0.0747, -0.0031, 0.1919, -0.2386, 0.0411, -0.2154]
# [0.1334, 0.1374, 1.0647, -0.0833, 0.2642, -0.2618]
# [0.1133, -0.0737, 0.2692, -0.2975, -0.0135, -0.0164]
# [-0.1598, 0.0721, 0.4088, -0.028, 0.3601, -0.1097]
# ...
