# %%
#from dv import AedatFile
import numpy as np

# %%
aedat_file = "../dataset/KH/train_test/raw_aedat/2020_07_29_19_50_07.aedat4"
with AedatFile(aedat_file) as f:
    # events will be a named numpy array
    events = np.hstack([packet for packet in f['events'].numpy()])

    # Access information of all events by type
    timestamps, x, y, polarities = events['timestamp'], events['x'], events['y'], events['polarity']
print(timestamps)
# Out:
# [1596019806543106 1596019806543117 1596019806543126 ... 1596020311753074
#  1596020311753074 1596020311753086]

# %%
1596020302

# %%
import numpy as np
location = "/home/student1/hyeongilee/slayerPytorch/example/dataset/KH/train_test/"
np_file = np.load(location+"52000.npy")

print(np_file.tolist())
# Out:
# [[255, 103, 1, 0], [66, 65, 1, 0], [64, 67, 1, 0], [291, 73, 1, 0], [225, 109, 1, 0], [296, 74, 1, 0], [116, 63, 1, 0], [217, 179, 1, 0], [46, 37, 1, 0], [132, 64, 1, 0], [100, 59, 1, 0], [273, 183, 1, 0], [247, 108, 1, 0], [241, 179, 1, 0], [227, 36, 1, 0], [200, 113, 1, 0], [193, 179, 1, 0], [181, 124, 1, 0], [174, 86, 1, 0], [171, 101, 1, 0], [110, 8, 1, 0], [95, 59, 1, 0], [86, 66, 1, 0], [65, 87, 1, 0], [58, 76, 1, 0], [48, 73, 1, 0], [27, 75, 1, 0], [11, 59, 1, 0], [277, 85, 1, 0], [273, 94, 1, 0], [269, 176, 1, 0], [267, 145, 1, 0], [260, 119, 1, 0], [246, 187, 1, 0], [239, 174, 1, 0], [236, 166, 1, 0], [223, 185, 1, 0], [214, 129, 1, 0], [210, 160, 1, 0], [210, 99, 1, 0], [210, 100, 1, 0], [205, 190, 1, 0], [203, 101, 1, 0], [181, 82, 1, 0], [163, 69, 1, 0], [148, 6, 1, 0], [145, 194, 1, 0], [127, 62, 1, 0], [126, 78, 1, 0], [90, 64, 1, 0], [88, 64, 1, 0], [87, 46, 1, 0], [73, 71, 1, 0], [64, 65, 1, 0], [52, 34, 1, 0], [52, 29, 1, 0], [39, 105, 1, 0], [286, 73, 1, 0], [282, 1
# ...
